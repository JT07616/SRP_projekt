# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

url = r"../data/atp_matches_all.csv"

data = pd.read_csv(url, delimiter=',')

print(data.head())
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2000-717      Orlando    Clay         32             A      20000501
# 1   2000-717      Orlando    Clay         32             A      20000501
# 2   2000-717      Orlando    Clay         32             A      20000501
# 3   2000-717      Orlando    Clay         32             A      20000501
# 4   2000-717      Orlando    Clay         32             A      20000501
#
#    match_num  winner_id  winner_seed winner_entry  ... w_bpFaced l_ace  l_df  \
# 0          1     102179          NaN          NaN  ...      15.0  13.0   4.0
# 1          2     103602          NaN            Q  ...       6.0   0.0   0.0
# 2          3     103387          NaN          NaN  ...       0.0   2.0   2.0
# 3          4     101733          NaN          NaN  ...      12.0   4.0   6.0
# 4          5     101727          4.0          NaN  ...       1.0   0.0   3.0
#
# ...

# %%
print(data.shape)
# Out:
# (50179, 49)

# %%
print(data.isna().sum())
# Out:
# tourney_id                0
# tourney_name              0
# surface                 118
# draw_size                 0
# tourney_level             0
# tourney_date              0
# match_num                 0
# winner_id                 0
# winner_seed           29382
# winner_entry          44287
# winner_name               0
# winner_hand              10
# winner_ht              2607
# winner_ioc                0
# winner_age               12
# winner_rank            1047
# winner_rank_points     1047
# loser_id                  0
# loser_seed            38994
# loser_entry           40316
# loser_name                0
# loser_hand               15
# loser_ht               4573
# loser_ioc                 0
# loser_age                22
# loser_rank             1724
# loser_rank_points      1724
# score                     1
# best_of                   0
# round                     0
# minutes                6966
# w_ace                  5728
# w_df                   5728
# ...

# %%
print(data.nunique())
# Out:
# tourney_id            2391
# tourney_name          1392
# surface                  4
# draw_size               11
# tourney_level            6
# tourney_date           730
# match_num              127
# winner_id             1300
# winner_seed             34
# winner_entry             4
# winner_name           1300
# winner_hand              3
# winner_ht               21
# winner_ioc             104
# winner_age            5920
# winner_rank           1040
# winner_rank_points    2738
# loser_id              1924
# loser_seed              35
# loser_entry              5
# loser_name            1924
# loser_hand               3
# loser_ht                21
# loser_ioc              111
# loser_age             6602
# loser_rank            1267
# loser_rank_points     2709
# score                 9426
# best_of                  2
# round                    9
# minutes                306
# w_ace                   52
# w_df                    23
# w_svpt                 223
# ...

# %%
print(data.dtypes)
# Out:
# tourney_id             object
# tourney_name           object
# surface                object
# draw_size               int64
# tourney_level          object
# tourney_date            int64
# match_num               int64
# winner_id               int64
# winner_seed           float64
# winner_entry           object
# winner_name            object
# winner_hand            object
# winner_ht             float64
# winner_ioc             object
# winner_age            float64
# winner_rank           float64
# winner_rank_points    float64
# loser_id                int64
# loser_seed            float64
# loser_entry            object
# loser_name             object
# loser_hand             object
# loser_ht              float64
# loser_ioc              object
# loser_age             float64
# loser_rank            float64
# loser_rank_points     float64
# score                  object
# best_of                 int64
# round                  object
# minutes               float64
# ...

# %%
for column in data:
    print(data[column].value_counts())
    input("...")
# Out:
# tourney_id
# 2015-540     127
# 2001-540     127
# 2005-520     127
# 2015-580     127
# 2007-560     127
#             ...
# 2000-D066      2
# 2007-D054      2
# 2004-D053      2
# 2006-D038      2
# 2013-D061      2
# Name: count, Length: 2391, dtype: int64
# ...
# tourney_name
# US Open                        2032
# Australian Open                2032
# Wimbledon                      2032
# Roland Garros                  2032
# Miami Masters                  1520
#                                ...
# Davis Cup G2 R1: CHN vs PHI       2
# Davis Cup G2 R1: TUN vs LAT       2
# Davis Cup G1 QF: CHN vs UZB       2
# Davis Cup G2 F: PAR vs URU        2
# Davis Cup G2 R1: ARM vs IRL       2
# Name: count, Length: 1392, dtype: int64
# ...
# surface
# Hard      26210
# Clay      16742
# Grass      5096
# Carpet     2013
# Name: count, dtype: int64
# ...
# draw_size
# 32     17209
# 128     8128
# 28      5157
# 4       5153
# 56      4840
# 48      3901
# 64      2840
# 96      2660
# ...

# %%
print(data.columns.values)
# Out:
# ['tourney_id' 'tourney_name' 'surface' 'draw_size' 'tourney_level'
#  'tourney_date' 'match_num' 'winner_id' 'winner_seed' 'winner_entry'
#  'winner_name' 'winner_hand' 'winner_ht' 'winner_ioc' 'winner_age'
#  'winner_rank' 'winner_rank_points' 'loser_id' 'loser_seed' 'loser_entry'
#  'loser_name' 'loser_hand' 'loser_ht' 'loser_ioc' 'loser_age' 'loser_rank'
#  'loser_rank_points' 'score' 'best_of' 'round' 'minutes' 'w_ace' 'w_df'
#  'w_svpt' 'w_1stIn' 'w_1stWon' 'w_2ndWon' 'w_SvGms' 'w_bpSaved'
#  'w_bpFaced' 'l_ace' 'l_df' 'l_svpt' 'l_1stIn' 'l_1stWon' 'l_2ndWon'
#  'l_SvGms' 'l_bpSaved' 'l_bpFaced']
